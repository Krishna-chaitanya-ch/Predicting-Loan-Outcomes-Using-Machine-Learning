# %% [markdown]
# # ml project
# Predicting Loan Outcomes.

# %%
# Importing the library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('/content/Bank data.xlsx')
df
# Out:
#      CustomerId CustomerName  CreditScore   Location  Gender  Age    Balance  \
# 0      15634602     Hargrave          619  Karnataka  Female   42        NaN
# 1      15647311         Hill          608     France  Female   41    8387.86
# 2      15619304         Onio          502  Karnataka  Female   42   15966.80
# 3      15701354         Boni          699  Karnataka  Female   39        NaN
# 4      15737888     Mitchell          850     France  Female   43   12551.82
# ..          ...          ...          ...        ...     ...  ...        ...
# 798    15570134     Padovano          683  Karnataka  Female   35   18753.66
# 799    15567367          Tao          601    Germany  Female   42      41.00
# 800    15747542        Perez          605  Karnataka    Male   52  202558.00
# 801    15762238       Fraser          671    Germany  Female   44   84745.30
# 802    15681554        Alley          614    Germany  Female   31   12599.38
#
# ...

# %%
# Retrieve the dimensions of the DataFrame (rows, columns)
df.shape
# Out:
# (803, 11)

# %%
# summary of dataset, including column names, data types, non-null counts, and memory usage.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 803 entries, 0 to 802
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       803 non-null    int64
#  1   CustomerName     803 non-null    object
#  2   CreditScore      803 non-null    int64
#  3   Location         803 non-null    object
#  4   Gender           803 non-null    object
#  5   Age              803 non-null    int64
#  6   Balance          728 non-null    float64
#  7   Loan Taken       803 non-null    object
#  8   Loan cleared     803 non-null    object
#  9   EstimatedSalary  797 non-null    float64
#  10  Exited           803 non-null    int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 69.1+ KB

# %%
# Convert the 'column_name' from object to float
df['EstimatedSalary'] = df['EstimatedSalary'].astype(float)
df['Balance']=df['Balance'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 803 entries, 0 to 802
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       803 non-null    int64
#  1   CustomerName     803 non-null    object
#  2   CreditScore      803 non-null    int64
#  3   Location         803 non-null    object
#  4   Gender           803 non-null    object
#  5   Age              803 non-null    int64
#  6   Balance          728 non-null    float64
#  7   Loan Taken       803 non-null    object
#  8   Loan cleared     803 non-null    object
#  9   EstimatedSalary  797 non-null    float64
#  10  Exited           803 non-null    int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 69.1+ KB

# %%
df.head()
# Out:
#    CustomerId CustomerName  CreditScore   Location  Gender  Age   Balance  \
# 0    15634602     Hargrave          619  Karnataka  Female   42       NaN
# 1    15647311         Hill          608     France  Female   41   8387.86
# 2    15619304         Onio          502  Karnataka  Female   42  15966.80
# 3    15701354         Boni          699  Karnataka  Female   39       NaN
# 4    15737888     Mitchell          850     France  Female   43  12551.82
#
#   Loan Taken Loan cleared  EstimatedSalary  Exited
# 0        yes          yes        101348.88       1
# 1        yes           no        112542.58       0
# 2         no          yes        113931.57       1
# 3         no           no         93826.63       0
# 4        yes          yes         79084.10       0

# %%
pd.isnull(df).sum()
# Out:
# CustomerId          0
# CustomerName        0
# CreditScore         0
# Location            0
# Gender              0
# Age                 0
# Balance            75
# Loan Taken          0
# Loan cleared        0
# EstimatedSalary     6
# Exited              0
# dtype: int64

# %%
df['Balance'].fillna(df['Balance'].mean(), inplace=True)
# Out:
# <ipython-input-90-de0732e4de79>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Balance'].fillna(df['Balance'].mean(), inplace=True)

# %%
df['EstimatedSalary'].fillna(df['EstimatedSalary'].mean(), inplace=True)
# Out:
# <ipython-input-91-ea63afb7f0a9>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['EstimatedSalary'].fillna(df['EstimatedSalary'].mean(), inplace=True)

# %%
df.head()
# Out:
#    CustomerId CustomerName  CreditScore   Location  Gender  Age  \
# 0    15634602     Hargrave          619  Karnataka  Female   42
# 1    15647311         Hill          608     France  Female   41
# 2    15619304         Onio          502  Karnataka  Female   42
# 3    15701354         Boni          699  Karnataka  Female   39
# 4    15737888     Mitchell          850     France  Female   43
#
#          Balance Loan Taken Loan cleared  EstimatedSalary  Exited
# 0  168154.755742        yes          yes        101348.88       1
# 1    8387.860000        yes           no        112542.58       0
# 2   15966.800000         no          yes        113931.57       1
# 3  168154.755742         no           no         93826.63       0
# 4   12551.820000        yes          yes         79084.10       0

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
sns.countplot(x='Exited',hue='Location', data=df)
# Out:
# <Axes: xlabel='Exited', ylabel='count'>

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Gender'] = label_encoder.fit_transform(df['Gender'])
df['Loan Taken'] = label_encoder.fit_transform(df['Loan Taken'])
df['Loan cleared'] = label_encoder.fit_transform(df['Loan cleared'])

# %%
df.drop(['CustomerId','CustomerName','Location'], axis=1, inplace=True)

# %%
# Split data into features and target
X = df.drop('Exited', axis=1)
y = df['Exited']

# %%
# Train-test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression

# %%
# making objects
rm=RandomForestClassifier()
cm=LogisticRegression()
dtree=DecisionTreeClassifier()
rfc=RandomForestClassifier()
svm=SVC()
knn=KNeighborsClassifier()
nb=GaussianNB()

# %%
# Models
models = {
    'Random Forest': rm,
    'Logistic Regression': cm,
    'Decision Tree': dtree,
    'Random Forest': rfc,
    'SVM': svm,
    'K-Nearest Neighbors': knn,
    'Naive Bayes': nb
}

# %%
# accuracy
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(f"{name}:{accuracy_score(y_test, y_pred):.2f}")
# Out:
# Random Forest:0.76
# Logistic Regression:0.80
# Decision Tree:0.65
# SVM:0.78
# K-Nearest Neighbors:0.81
# Naive Bayes:0.26

# %%
 # confusion matrix
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(f"{name}\nConfusion Matrix:\n{confusion_matrix(y_test, y_pred)}\n")
# Out:
# Random Forest
# Confusion Matrix:
# [[115  13]
#  [ 22  11]]
#
# Logistic Regression
# Confusion Matrix:
# [[124   4]
#  [ 29   4]]
#
# Decision Tree
# Confusion Matrix:
# [[98 30]
#  [22 11]]
#
# SVM
# Confusion Matrix:
# [[120   8]
#  [ 28   5]]
#
# K-Nearest Neighbors
# Confusion Matrix:
# [[118  10]
#  [ 21  12]]
#
# Naive Bayes
# Confusion Matrix:
# [[ 10 118]
#  [  1  32]]

# %%
# classification report
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(f"{name}\nClassification Report:\n{classification_report(y_test, y_pred)}\n")
# Out:
# Random Forest
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87       128
#            1       0.48      0.30      0.37        33
#
#     accuracy                           0.79       161
#    macro avg       0.66      0.61      0.62       161
# weighted avg       0.76      0.79      0.77       161
#
#
# Logistic Regression
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.97      0.88       128
#            1       0.50      0.12      0.20        33
#
#     accuracy                           0.80       161
#    macro avg       0.66      0.54      0.54       161
# weighted avg       0.75      0.80      0.74       161
#
#
# Decision Tree
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.76      0.78       128
#            1       0.21      0.24      0.22        33
#
# ...
